# %%
"""Name-Jigyasa Rana
University roll no.-2028439
Section-P
"""

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
data = pd.read_csv(r"C:\Users\ASUS\Downloads\market_basket_dataset.csv")
data.head(5)
# Out:
#    Item1   Item2   Item3 Item4
# 0   Milk   Bread  Butter  Eggs
# 1  Bread  Butter     Jam   NaN
# 2   Milk   Bread    Eggs   NaN
# 3   Milk   Bread  Butter   Jam
# 4  Bread    Eggs     Tea   NaN

# %%
transactions = df.values.tolist()

# %%
te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)

# %%
basket = pd.DataFrame(te_array, columns=te.columns_)
basket.head()
# Out:
#    False  True
# 0  False   True
# 1   True   True
# 2   True   True
# 3   True   True
# 4   True   True

# %%
frequent_itemsets = apriori(basket, min_support=0.3, use_colnames=True)

# %%
frequent_itemsets
# Out:
#    support                  itemsets
# 0      0.8        frozenset({False})
# 1      1.0         frozenset({True})
# 2      0.8  frozenset({False, True})

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)

# %%
rules
# Out:
#           antecedents         consequents  antecedent support  \
# 0  frozenset({False})   frozenset({True})                 0.8
# 1   frozenset({True})  frozenset({False})                 1.0
#
#    consequent support  support  confidence  lift  representativity  leverage  \
# 0                 1.0      0.8         1.0   1.0               1.0       0.0
# 1                 0.8      0.8         0.8   1.0               1.0       0.0
#
#    conviction  zhangs_metric  jaccard  certainty  kulczynski
# 0         inf            0.0      0.8        0.0         0.9
# 1         1.0            0.0      0.8        0.0         0.9

# %%
frequent_itemsets[['support','itemsets']]
# Out:
#    support                  itemsets
# 0      0.8        frozenset({False})
# 1      1.0         frozenset({True})
# 2      0.8  frozenset({False, True})

# %%
rules[['antecedents','consequents','support','confidence']]
# Out:
#           antecedents         consequents  support  confidence
# 0  frozenset({False})   frozenset({True})      0.8         1.0
# 1   frozenset({True})  frozenset({False})      0.8         0.8
